# %% [markdown]
# # **Preprocessing with MNE**

# %%
# Import the MNE library for EEG analysis
import mne
#%matplotlib qt
# Read raw EEG data from an EDF file
rawEEG = mne.io.read_raw_edf('EDF_EEG.edf', preload=True)
rawEEG.plot(block=False, duration=10.0, title='raw EEG data')
rawEEG.filter(.1,30)
rawEEG.plot(block=False, duration=10.0, title='Filtered EEG data')
# Out:
# Extracting EDF parameters from c:\project\mne\EDF_EEG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 197631  =      0.000 ...   771.996 secs...
# Using matplotlib as 2D backend.
# C:\Users\Vi-1\AppData\Local\Temp\ipykernel_8528\1311543281.py:5: RuntimeWarning: Number of records from the header does not match the file size (perhaps the recording was not stopped before exiting). Inferring from the file size.
#   rawEEG = mne.io.read_raw_edf('EDF_EEG.edf', preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 8449 samples (33.004 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <MNEBrowseFigure size 1000x1000 with 4 Axes>

# %% [markdown]
# ### *Plotting EEG*

# %%
# Plot the raw EEG data (non-interactive)
rawEEG.plot(block=False, duration=10.0, title='raw EEG data')
# Out:
# <MNEBrowseFigure size 1000x1000 with 4 Axes>

# %% [markdown]
# ### *General information of our data*

# %%
# Display information about the raw EEG data
rawEEG.info
print(rawEEG.info['nchan'])
# Out:
# 19

# %% [markdown]
# ### *Filtering EEG*

# %%
#Filtering the EEG
rawEEG.filter(0, 30)
# filter(lower frequency, higher frequency)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 113 samples (0.441 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <RawEDF | EDF_EEG.edf, 19 x 197632 (772.0 s), ~28.7 MiB, data loaded>

# %%
#Create a variable for filtered EEG
EEGFiltered = rawEEG.copy(). filter(0.1, 40)
# EEGArtifacted
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 8449 samples (33.004 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s

# %%
EEGFiltered = mne.io.read_raw_fif('EEGFiltered.fif', preload=True)
# Out:
# Opening raw data file EEGFiltered.fif...
# Isotrak not found
#     Range : 0 ... 197631 =      0.000 ...   771.996 secs
# Ready.
# Reading 0 ... 197631  =      0.000 ...   771.996 secs...
# C:\Users\Vi-1\AppData\Local\Temp\ipykernel_8528\1059112096.py:1: RuntimeWarning: This filename (EEGFiltered.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   EEGFiltered = mne.io.read_raw_fif('EEGFiltered.fif', preload=True)

# %% [markdown]
# ### *Saving Steps*

# %%
# Saving the filtered EEG data to a file
EEGFiltered.save('EEGFiltered.fif')
# Out:
# Writing c:\project\mne\EEGFiltered.fif
# Closing c:\project\mne\EEGFiltered.fif
# [done]
# C:\Users\Vi-1\AppData\Local\Temp\ipykernel_8528\119190718.py:2: RuntimeWarning: This filename (c:\project\mne\EEGFiltered.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   EEGFiltered.save('EEGFiltered.fif')
# [WindowsPath('c:/project/mne/EEGFiltered.fif')]

# %%
EEGFiltered = mne.io.read_raw_fif('EEGFiltered.fif', preload=True)
# Out:
# Opening raw data file EEGFiltered.fif...
# Isotrak not found
#     Range : 0 ... 197631 =      0.000 ...   771.996 secs
# Ready.
# Reading 0 ... 197631  =      0.000 ...   771.996 secs...
# C:\Users\Vi-1\AppData\Local\Temp\ipykernel_8528\1059112096.py:1: RuntimeWarning: This filename (EEGFiltered.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   EEGFiltered = mne.io.read_raw_fif('EEGFiltered.fif', preload=True)

# %% [markdown]
# ### *Removing artifacts considering ICA*

# %%
rawEEG.plot()
# Out:
# <MNEBrowseFigure size 1000x1000 with 4 Axes>
# Channels marked as bad:
# none

# %%
from mne.preprocessing import ICA
# Creating a standard 10-20 system montage
montage = mne.channels.make_standard_montage('standard_1020')
#Set the created montage to EEG
rawEEG.set_montage(montage)
# Out:
# <RawEDF | EDF_EEG.edf, 19 x 197632 (772.0 s), ~28.7 MiB, data loaded>

# %%
#Importing necessary function
from mne.preprocessing import ICA
# Create ICA
ICAComponents = ICA(15)
# Fit to Data
ICAComponents.fit(rawEEG)
#plottinh the components
ICAComponents.plot_components()
# Out:
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 2.9s.
# <MNEFigure size 1218.75x913.75 with 15 Axes>

# %%
#Exclude artifactual components
ICAComponents.exclude = [1,2]
rawEEG_ICA = ICAComponents.apply(rawEEG)
# Out:
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 19 PCA components

# %%
#Plot after ICA artifact removal
rawEEG_ICA.plot()
# Out:
# <MNEBrowseFigure size 1000x1000 with 4 Axes>
# Channels marked as bad:
# none

# %%
import matplotlib.pyplot as plt
rawEEG.plot()
plt.show()
# Out:
# Channels marked as bad:
# none

# %%
# Out:
# Opening raw data file EEGFiltered.fif...
# Isotrak not found
#     Range : 0 ... 197631 =      0.000 ...   771.996 secs
# Ready.
# Reading 0 ... 197631  =      0.000 ...   771.996 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
# C:\Users\Vi-1\AppData\Local\Temp\ipykernel_900\3084270201.py:10: RuntimeWarning: This filename (EEGFiltered.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data_raw = mne.io.read_raw_fif(file_path, preload=True)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 18
#      16 # تشخیص آرتیفکت‌ها با ICA
#      17 ica = mne.preprocessing.ICA(n_components=20, random_state=42)
# ---> 18 ica.fit(data_filtered)
#      19 ica.exclude = [0, 1]  # حذف اجزاء نویزی شناسایی شده
#      20 data_cleaned = data_filtered.copy()
#
# File <decorator-gen-348>:12, in fit(self, inst, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#
# File c:\Users\Vi-1\AppData\Local\Programs\Python\Python313\Lib\site-packages\mne\preprocessing\ica.py:724, in ICA.fit(self, inst, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#     722 # n_components could be float 0 < x < 1, but that's okay here
#     723 if self.n_components is not None and self.n_components > len(picks):
# --> 724     raise ValueError(
#     725         f"ica.n_components ({self.n_components}) cannot "
#     726         f"be greater than len(picks) ({len(picks)})"
#     727     )
#     729 # filter out all the channels the raw wouldn't have initialized
#     730 self.info = pick_info(inst.info, picks)
#
# ValueError: ica.n_components (20) cannot be greater than len(picks) (19)
